# %%
# Data manipulation libraries
import numpy as np
import pandas as pd
from collections import defaultdict

import matplotlib.pyplot as plt
# System libraries
import glob
import os
import sys

# Library for reading through pdf
# pip install pymupdf
# pip install fitz
import fitz

# %% [markdown]
# **Data Collection**
# Using a bash script to save all the PDF files from the [google mobility site](https://www.google.com/covid19/mobility/) and store them in a folder.

# %%
# %%bash
#
# mkdir -p mobility_pdfs/
# cd mobility_pdfs/
# # hacky way to create a list of states in USA
# states_list="Alabama Alaska Arizona Arkansas California Colorado Connecticut Delaware Florida Georgia Hawaii Idaho Illinois Indiana Iowa Kansas Kentucky Louisiana Maine Maryland Massachusetts Michigan Minnesota Mississippi Missouri Montana Nebraska Nevada New_Hampshire New_Jersey New_Mexico New_York North_Carolina North_Dakota Ohio Oklahoma Oregon Pennsylvania Rhode_Island South_Carolina South_Dakota Tennessee Texas Utah Vermont Virginia Washington West_Virginia Wisconsin Wyoming"
# country_list = "US Spain Italy France Germany"
# country_list_short = "US ES IT FR DE"
# date="2020-04-05"
#
# # Get the pdfs for the mobility information of the states
# for state in $states_list ; do
#     curl -s -O https://www.gstatic.com/covid19/mobility/${date}_US_${state}_Mobility_Report_en.pdf
# done
# # Get the pdf for the US country
# curl -s -o ${date}_US_US_Mobility_Report_en.pdf https://www.gstatic.com/covid19/mobility/${date}_US_Mobility_Report_en.pdf
#
# for country in $country_list_short ; do
#     curl -s -O https://www.gstatic.com/covid19/mobility/${date}_${country}_Mobility_Report_en.pdf
# done
# Out:
# bash: line 6: country_list: command not found
# bash: line 7: country_list_short: command not found

# %% [markdown]
# **PDF Parser**
# Obtained this script online for parsing from an incoming stream of data and reading the plots in the page.

# %%
def parse_streaming_data(stream):
    data_raw = []
    data_transformed = []
    rotparams = None
    npatches = 0
    for line in stream.splitlines():
        if line.endswith(" cm"):
            # page 146 of https://www.adobe.com/content/dam/acom/en/devnet/pdf/pdfs/pdf_reference_archives/PDFReference.pdf
            rotparams = list(map(float,line.split()[:-1]))
        elif line.endswith(" l"):
            x,y = list(map(float,line.split()[:2]))
            a,b,c,d,e,f = rotparams
            xp = a*x+c*y+e
            yp = b*x+d*y+f
            data_transformed.append([xp,yp])
            data_raw.append([x,y])
        elif line.endswith(" m"):
            npatches += 1
        else:
            pass
    data_raw = np.array(data_raw)
    basex, basey = data_raw[-1]
    good = False
    if basex == 0.:
        data_raw[:,1] = basey - data_raw[:,1]
        data_raw[:,1] *= 100/60.
        data_raw = data_raw[data_raw[:,1]!=0.]
        if npatches == 1: good = True
    return dict(data=np.array(data_raw), npatches=npatches, good=good)

# %% [markdown]
# **PDF Parser**
# The method below parses the pdf by reading lines from it iteratviely and based on specified conditions, stores the information in arrays.

# %%
def parse_page(doc, ipage, verbose=False):
    # Set of the categories required
    categories_list = [
        "Retail & recreation",
        "Grocery & pharmacy",
        "Parks",
        "Transit stations",
        "Workplace",
        "Residential",
    ]
    
    counties = []
    curr_county = None
    curr_category = None
    data = defaultdict(lambda: defaultdict(list))
    pagetext = doc.getPageText(ipage)
    lines = pagetext.splitlines()
    tickdates = list(filter(lambda x:len(x.split())==3, set(lines[-10:])))
    #print (tickdates)
    count  =0
    for line in lines:
        # Removing unwanted data from the page
        if ("* Not enough data") in line: continue
        if ("needs a significant volume of data") in line: continue

        # If found the category line, add it to the dictionary, else keep iterating over.
        if any(line.startswith(category) for category in categories_list):
            curr_category = line
        elif curr_category:
            data[curr_county][curr_category].append(line)

        # Filtering data to find the county information
        if (all(category not in line for category in categories_list)
            and ("compared to baseline" not in line)
            and ("Not enough data" not in line)
           ):
            # Only two counties per page
            if len(data.keys()) == 2: break
            count +=1
            #print (line, count)    
            counties.append(line)
            curr_county = line
            
    # Debugging entry skipping 
    if (ipage==5):
        print (ipage,counties, "\n")
    for county in data :
        print (county)
        newdata = {}
    for county in data:
        newdata[county] = {}
        
        for category in data[county]:
            # Skipping the ones with no data. We get to know that based on the space and * in the Pdf
            if category.endswith(" "): continue
            temp = [x for x in data[county][category] if "compared to baseline" in x]
            if not temp: continue
            percent = int(temp[0].split()[0].replace("%",""))
            newdata[county][category.strip()] = percent
    data = newdata
    for county in data :
        print (county, data[county])
    tomatch = []
    #Create a list of counties and the available categories for the given county
    for county in counties:
        for category in categories_list:
            if category in data[county]:
                tomatch.append([county,category,data[county][category]])
                

    print(len(tomatch))
    print(data)

    # Get the readable plots from the page ( Since there are broken and empty plots in the page)
    readableplots = []
    xrefs = sorted(doc.getPageXObjectList(ipage), key=lambda x:int(x[1].replace("X","")))
    for i,xref in enumerate(xrefs):
        stream = doc.xrefStream(xref[0]).decode()
        info = parse_streaming_data(stream)
        if not info["good"]: continue
        readableplots.append(info)
    
    print(len(readableplots))
    
    ret = []
    

    
    for m,g in zip(tomatch,readableplots):
        xs = g["data"][:,0]
        ys = g["data"][:,1]
        maxys = ys[np.where(xs==xs.max())[0]]
        maxy = maxys[np.argmax(np.abs(maxys))]
        
        
        # Parse the dates as text and then based on min to max value, create a range of dates and store it in the dictionary
        ts = list(map(lambda x: pd.Timestamp(x.split(None,1)[-1] + ", 2020"), tickdates))
        low, high = min(ts), max(ts)
        dr = list(map(lambda x:str(x).split()[0], pd.date_range(low, high, freq="D")))
        lutpairs = list(zip(np.linspace(0,200,len(dr)),dr))

        dates = []
        values = []
        asort = xs.argsort()
        xs = xs[asort]
        ys = ys[asort]
        for x,y in zip(xs,ys):
            date = min(lutpairs, key=lambda v:abs(v[0]-x))[1]
            dates.append(date)
            values.append(round(y,3))

        ret.append(dict(
            county=m[0],category=m[1],change=m[2],
            values=values,
            dates=dates,
            changecalc=maxy,
        ))
    return ret

# %%
# Create the dataframe for the county and state data.
def parse_state(state):
    doc = fitz.Document(f"mobility_pdfs/2020-04-05_US_{state}_Mobility_Report_en.pdf")
    data = []
    # 2 because we are skipping the first 2 pages from the PDF.
    for i in range(2,doc.pageCount-1):
        #print (i, "The actual page")
        for entry in parse_page(doc, i):
            entry["state"] = state
            entry["page"] = i
            print (i, "the page numbers")
            data.append(entry)
    outname = f"data/{state}.json.gz"
    df = pd.DataFrame(data)
    #ncounties = df['county'].nunique()
    ncounties =df['county'].nunique()
    print(f"Parsed {len(df)} plots for {ncounties} counties in {state}")
    df = df[["state","county","category","change","changecalc","dates", "values","page"]]
    return df

# %%
# Create the dataframe for the specific state
string = "Texas"
df = parse_state(string)
csv_name = string +"_mobility.csv"
df.to_csv(csv_name)
parse_state(string).head(100)
# Out:
# Anderson County
# Andrews County
# Anderson County {'Retail & recreation': -39, 'Grocery & pharmacy': -6, 'Workplace': -26}
# Andrews County {'Retail & recreation': -45, 'Grocery & pharmacy': -40, 'Workplace': -31}
# 6
# {'Anderson County': {'Retail & recreation': -39, 'Grocery & pharmacy': -6, 'Workplace': -26}, 'Andrews County': {'Retail & recreation': -45, 'Grocery & pharmacy': -40, 'Workplace': -31}}
# 6
# 2 the page numbers
# 2 the page numbers
# 2 the page numbers
# 2 the page numbers
# 2 the page numbers
# 2 the page numbers
# Angelina County
# Aransas County
# Angelina County {'Retail & recreation': -48, 'Grocery & pharmacy': -17, 'Transit stations': -40, 'Workplace': -27, 'Residential': 15}
# Aransas County {'Retail & recreation': -46, 'Grocery & pharmacy': -35, 'Workplace': -34}
# 8
# {'Angelina County': {'Retail & recreation': -48, 'Grocery & pharmacy': -17, 'Transit stations': -40, 'Workplace': -27, 'Residential': 15}, 'Aransas County': {'Retail & recreation': -46, 'Grocery & pharmacy': -35, 'Workplace': -34}}
# 7
# 3 the page numbers
# 3 the page numbers
# 3 the page numbers
# 3 the page numbers
# 3 the page numbers
# 3 the page numbers
# 3 the page numbers
# Archer County
# Atascosa County
# Archer County {}
# Atascosa County {'Retail & recreation': -29, 'Grocery & pharmacy': -19, 'Transit stations': -70, 'Workplace': -27}
# 4
# {'Archer County': {}, 'Atascosa County': {'Retail & recreation': -29, 'Grocery & pharmacy': -19, 'Transit stations': -70, 'Workplace': -27}}
# 4
# 4 the page numbers
# 4 the page numbers
# 4 the page numbers
# 4 the page numbers
# 5 ['Austin County', 'Bailey County']
#
# Austin County
# Bailey County
# Austin County {'Retail & recreation': -37, 'Grocery & pharmacy': -22, 'Workplace': -27}
# Bailey County {'Grocery & pharmacy': -8}
# 4
# {'Austin County': {'Retail & recreation': -37, 'Grocery & pharmacy': -22, 'Workplace': -27}, 'Bailey County': {'Grocery & pharmacy': -8}}
# 4
# 5 the page numbers
# 5 the page numbers
# 5 the page numbers
# 5 the page numbers
# Bandera County
# Bastrop County
# Bandera County {'Retail & recreation': -45, 'Grocery & pharmacy': -5, 'Workplace': -40}
# Bastrop County {'Retail & recreation': -40, 'Grocery & pharmacy': -29, 'Workplace': -39, 'Residential': 18}
# 7
# {'Bandera County': {'Retail & recreation': -45, 'Grocery & pharmacy': -5, 'Workplace': -40}, 'Bastrop County': {'Retail & recreation': -40, 'Grocery & pharmacy': -29, 'Workplace': -39, 'Residential': 18}}
# 7
# 6 the page numbers
# 6 the page numbers
# 6 the page numbers
# 6 the page numbers
# 6 the page numbers
# 6 the page numbers
# 6 the page numbers
# Bee County
# Bell County
# Bee County {'Retail & recreation': -34, 'Grocery & pharmacy': -24, 'Workplace': -29}
# Bell County {'Retail & recreation': -42, 'Grocery & pharmacy': -25, 'Parks': -30, 'Transit stations': -38, 'Workplace': -36, 'Residential': 11}
# 9
# {'Bee County': {'Retail & recreation': -34, 'Grocery & pharmacy': -24, 'Workplace': -29}, 'Bell County': {'Retail & recreation': -42, 'Grocery & pharmacy': -25, 'Parks': -30, 'Transit stations': -38, 'Workplace': -36, 'Residential': 11}}
# 9
# 7 the page numbers
# 7 the page numbers
# 7 the page numbers
# 7 the page numbers
# 7 the page numbers
# 7 the page numbers
# 7 the page numbers
# 7 the page numbers
# 7 the page numbers
# Bexar County
# Blanco County
# Bexar County {'Retail & recreation': -48, 'Grocery & pharmacy': -22, 'Parks': -61, 'Transit stations': -50, 'Workplace': -40, 'Residential': 14}
# Blanco County {'Retail & recreation': -67, 'Grocery & pharmacy': -20}
# 8
# {'Bexar County': {'Retail & recreation': -48, 'Grocery & pharmacy': -22, 'Parks': -61, 'Transit stations': -50, 'Workplace': -40, 'Residential': 14}, 'Blanco County': {'Retail & recreation': -67, 'Grocery & pharmacy': -20}}
# 8
# 8 the page numbers
# 8 the page numbers
# 8 the page numbers
# 8 the page numbers
# 8 the page numbers
# 8 the page numbers
# 8 the page numbers
# 8 the page numbers
# Bosque County
# Bowie County
# Bosque County {'Retail & recreation': -37, 'Grocery & pharmacy': -7, 'Workplace': -36}
# Bowie County {'Retail & recreation': -45, 'Grocery & pharmacy': -13, 'Transit stations': -24, 'Workplace': -30, 'Residential': 11}
# 8
# {'Bosque County': {'Retail & recreation': -37, 'Grocery & pharmacy': -7, 'Workplace': -36}, 'Bowie County': {'Retail & recreation': -45, 'Grocery & pharmacy': -13, 'Transit stations': -24, 'Workplace': -30, 'Residential': 11}}
# 8
# 9 the page numbers
# 9 the page numbers
# 9 the page numbers
# 9 the page numbers
# 9 the page numbers
# 9 the page numbers
# 9 the page numbers
# 9 the page numbers
# Brazoria County
# Brazos County
# Brazoria County {'Retail & recreation': -41, 'Grocery & pharmacy': -19, 'Parks': -12, 'Transit stations': -26, 'Workplace': -33, 'Residential': 13}
# Brazos County {'Retail & recreation': -51, 'Grocery & pharmacy': -29, 'Parks': -49, 'Workplace': -42, 'Residential': 16}
# 11
# {'Brazoria County': {'Retail & recreation': -41, 'Grocery & pharmacy': -19, 'Parks': -12, 'Transit stations': -26, 'Workplace': -33, 'Residential': 13}, 'Brazos County': {'Retail & recreation': -51, 'Grocery & pharmacy': -29, 'Parks': -49, 'Workplace': -42, 'Residential': 16}}
# 11
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# 10 the page numbers
# Brewster County
# Brooks County
# Brewster County {'Retail & recreation': -52, 'Grocery & pharmacy': -43}
# Brooks County {'Retail & recreation': -55, 'Grocery & pharmacy': -9, 'Transit stations': -42}
# 5
# {'Brewster County': {'Retail & recreation': -52, 'Grocery & pharmacy': -43}, 'Brooks County': {'Retail & recreation': -55, 'Grocery & pharmacy': -9, 'Transit stations': -42}}
# 4
# 11 the page numbers
# 11 the page numbers
# 11 the page numbers
# 11 the page numbers
# Brown County
# Burleson County
# Brown County {'Retail & recreation': -42, 'Grocery & pharmacy': -21, 'Workplace': -28}
# Burleson County {'Retail & recreation': -34, 'Grocery & pharmacy': -10, 'Workplace': -22}
# 6
# {'Brown County': {'Retail & recreation': -42, 'Grocery & pharmacy': -21, 'Workplace': -28}, 'Burleson County': {'Retail & recreation': -34, 'Grocery & pharmacy': -10, 'Workplace': -22}}
# 6
# 12 the page numbers
# 12 the page numbers
# 12 the page numbers
# 12 the page numbers
# 12 the page numbers
# 12 the page numbers
# Burnet County
# Caldwell County
# Burnet County {'Retail & recreation': -41, 'Grocery & pharmacy': -26, 'Workplace': -37}
# Caldwell County {'Retail & recreation': -42, 'Grocery & pharmacy': -41, 'Transit stations': -43, 'Workplace': -37}
# 7
# {'Burnet County': {'Retail & recreation': -41, 'Grocery & pharmacy': -26, 'Workplace': -37}, 'Caldwell County': {'Retail & recreation': -42, 'Grocery & pharmacy': -41, 'Transit stations': -43, 'Workplace': -37}}
# 7
# 13 the page numbers
# 13 the page numbers
# 13 the page numbers
# 13 the page numbers
# 13 the page numbers
# 13 the page numbers
# 13 the page numbers
# Calhoun County
# Callahan County
# Calhoun County {'Retail & recreation': -43, 'Grocery & pharmacy': -17, 'Workplace': -21}
# Callahan County {'Retail & recreation': -30, 'Grocery & pharmacy': -15, 'Transit stations': -28}
# 6
# {'Calhoun County': {'Retail & recreation': -43, 'Grocery & pharmacy': -17, 'Workplace': -21}, 'Callahan County': {'Retail & recreation': -30, 'Grocery & pharmacy': -15, 'Transit stations': -28}}
# 6
# 14 the page numbers
# 14 the page numbers
# 14 the page numbers
# 14 the page numbers
# 14 the page numbers
# 14 the page numbers
# Cameron County
# Camp County
# Cameron County {'Retail & recreation': -68, 'Grocery & pharmacy': -46, 'Parks': -78, 'Transit stations': -71, 'Workplace': -43, 'Residential': 19}
# Camp County {'Grocery & pharmacy': -9}
# 7
# {'Cameron County': {'Retail & recreation': -68, 'Grocery & pharmacy': -46, 'Parks': -78, 'Transit stations': -71, 'Workplace': -43, 'Residential': 19}, 'Camp County': {'Grocery & pharmacy': -9}}
# 7
# 15 the page numbers
# 15 the page numbers
# 15 the page numbers
# 15 the page numbers
# 15 the page numbers
# 15 the page numbers
# 15 the page numbers
# Carson County
# Cass County
# Carson County {}
# Cass County {'Retail & recreation': -36, 'Grocery & pharmacy': -3, 'Transit stations': -25, 'Workplace': -36}
# 4
# {'Carson County': {}, 'Cass County': {'Retail & recreation': -36, 'Grocery & pharmacy': -3, 'Transit stations': -25, 'Workplace': -36}}
# 4
# 16 the page numbers
# 16 the page numbers
# 16 the page numbers
# 16 the page numbers
# Castro County
# Chambers County
# Castro County {}
# Chambers County {'Retail & recreation': -47, 'Grocery & pharmacy': -22, 'Transit stations': -54, 'Workplace': -27}
# 4
# {'Castro County': {}, 'Chambers County': {'Retail & recreation': -47, 'Grocery & pharmacy': -22, 'Transit stations': -54, 'Workplace': -27}}
# 4
# 17 the page numbers
# 17 the page numbers
# 17 the page numbers
# 17 the page numbers
# Cherokee County
# Childress County
# Cherokee County {'Retail & recreation': -28, 'Grocery & pharmacy': -12, 'Workplace': -27}
# Childress County {'Retail & recreation': -36, 'Grocery & pharmacy': -20}
# 5
# {'Cherokee County': {'Retail & recreation': -28, 'Grocery & pharmacy': -12, 'Workplace': -27}, 'Childress County': {'Retail & recreation': -36, 'Grocery & pharmacy': -20}}
# 5
# 18 the page numbers
# 18 the page numbers
# 18 the page numbers
# 18 the page numbers
# 18 the page numbers
# Clay County
# Coke County
# Clay County {}
# Coke County {}
# 0
# {'Clay County': {}, 'Coke County': {}}
# 0
# Coleman County
# Collin County
# Coleman County {'Grocery & pharmacy': -19}
# Collin County {'Retail & recreation': -55, 'Grocery & pharmacy': -34, 'Parks': -33, 'Transit stations': -41, 'Workplace': -47, 'Residential': 15}
# 7
# {'Coleman County': {'Grocery & pharmacy': -19}, 'Collin County': {'Retail & recreation': -55, 'Grocery & pharmacy': -34, 'Parks': -33, 'Transit stations': -41, 'Workplace': -47, 'Residential': 15}}
# 7
# 20 the page numbers
# 20 the page numbers
# 20 the page numbers
# 20 the page numbers
# 20 the page numbers
# 20 the page numbers
# 20 the page numbers
# Colorado County
# Comal County
# Colorado County {'Retail & recreation': -44, 'Grocery & pharmacy': -11, 'Transit stations': -45, 'Workplace': -24}
# Comal County {'Retail & recreation': -51, 'Grocery & pharmacy': -35, 'Parks': -62, 'Transit stations': -24, 'Workplace': -41, 'Residential': 14}
# 10
# {'Colorado County': {'Retail & recreation': -44, 'Grocery & pharmacy': -11, 'Transit stations': -45, 'Workplace': -24}, 'Comal County': {'Retail & recreation': -51, 'Grocery & pharmacy': -35, 'Parks': -62, 'Transit stations': -24, 'Workplace': -41, 'Residential': 14}}
# 10
# 21 the page numbers
# 21 the page numbers
# 21 the page numbers
# 21 the page numbers
# 21 the page numbers
# 21 the page numbers
# 21 the page numbers
# 21 the page numbers
# 21 the page numbers
# 21 the page numbers
# Comanche County
# Cooke County
# Comanche County {'Retail & recreation': -28, 'Grocery & pharmacy': -29}
# Cooke County {'Retail & recreation': -41, 'Grocery & pharmacy': -10, 'Workplace': -35}
# 5
# {'Comanche County': {'Retail & recreation': -28, 'Grocery & pharmacy': -29}, 'Cooke County': {'Retail & recreation': -41, 'Grocery & pharmacy': -10, 'Workplace': -35}}
# 5
# 22 the page numbers
# 22 the page numbers
# 22 the page numbers
# 22 the page numbers
# 22 the page numbers
# Coryell County
# Crane County
# Coryell County {'Retail & recreation': -34, 'Grocery & pharmacy': -17, 'Parks': -5, 'Workplace': -32, 'Residential': 15}
# Crane County {'Grocery & pharmacy': -20}
# 6
# {'Coryell County': {'Retail & recreation': -34, 'Grocery & pharmacy': -17, 'Parks': -5, 'Workplace': -32, 'Residential': 15}, 'Crane County': {'Grocery & pharmacy': -20}}
# 5
# 23 the page numbers
# 23 the page numbers
# 23 the page numbers
# 23 the page numbers
# 23 the page numbers
# Crockett County
# Crosby County
# Crockett County {}
# Crosby County {}
# 0
# {'Crockett County': {}, 'Crosby County': {}}
# 0
# Culberson County
# Dallam County
# Culberson County {'Retail & recreation': -54, 'Transit stations': -40}
# Dallam County {'Retail & recreation': -38, 'Grocery & pharmacy': -21}
# 4
# {'Culberson County': {'Retail & recreation': -54, 'Transit stations': -40}, 'Dallam County': {'Retail & recreation': -38, 'Grocery & pharmacy': -21}}
# 4
# 25 the page numbers
# 25 the page numbers
# 25 the page numbers
# 25 the page numbers
# Dallas County
# Dawson County
# Dallas County {'Retail & recreation': -49, 'Grocery & pharmacy': -20, 'Parks': -46, 'Transit stations': -51, 'Workplace': -42, 'Residential': 15}
# Dawson County {'Retail & recreation': -35, 'Grocery & pharmacy': -9}
# 8
# {'Dallas County': {'Retail & recreation': -49, 'Grocery & pharmacy': -20, 'Parks': -46, 'Transit stations': -51, 'Workplace': -42, 'Residential': 15}, 'Dawson County': {'Retail & recreation': -35, 'Grocery & pharmacy': -9}}
# 8
# 26 the page numbers
# 26 the page numbers
# 26 the page numbers
# 26 the page numbers
# 26 the page numbers
# 26 the page numbers
# 26 the page numbers
# 26 the page numbers
# DeWitt County
# Deaf Smith County
# DeWitt County {'Retail & recreation': -38, 'Grocery & pharmacy': -27, 'Workplace': -25}
# Deaf Smith County {'Retail & recreation': -26, 'Grocery & pharmacy': -14, 'Workplace': -20}
# 6
# {'DeWitt County': {'Retail & recreation': -38, 'Grocery & pharmacy': -27, 'Workplace': -25}, 'Deaf Smith County': {'Retail & recreation': -26, 'Grocery & pharmacy': -14, 'Workplace': -20}}
# 6
# 27 the page numbers
# 27 the page numbers
# 27 the page numbers
# 27 the page numbers
# 27 the page numbers
# 27 the page numbers
# Delta County
# Denton County
# Delta County {}
# Denton County {'Retail & recreation': -52, 'Grocery & pharmacy': -31, 'Parks': -31, 'Transit stations': -38, 'Workplace': -45, 'Residential': 15}
# 6
# {'Delta County': {}, 'Denton County': {'Retail & recreation': -52, 'Grocery & pharmacy': -31, 'Parks': -31, 'Transit stations': -38, 'Workplace': -45, 'Residential': 15}}
# 6
# 28 the page numbers
# 28 the page numbers
# 28 the page numbers
# 28 the page numbers
# 28 the page numbers
# 28 the page numbers
# Dimmit County
# Donley County
# Dimmit County {'Retail & recreation': -31, 'Grocery & pharmacy': -24}
# Donley County {}
# 2
# {'Dimmit County': {'Retail & recreation': -31, 'Grocery & pharmacy': -24}, 'Donley County': {}}
# 2
# 29 the page numbers
# 29 the page numbers
# Duval County
# Eastland County
# Duval County {'Grocery & pharmacy': -30}
# Eastland County {'Retail & recreation': -42, 'Grocery & pharmacy': -12, 'Transit stations': -36, 'Workplace': -25}
# 5
# {'Duval County': {'Grocery & pharmacy': -30}, 'Eastland County': {'Retail & recreation': -42, 'Grocery & pharmacy': -12, 'Transit stations': -36, 'Workplace': -25}}
# 5
# 30 the page numbers
# 30 the page numbers
# 30 the page numbers
# 30 the page numbers
# 30 the page numbers
# Ector County
# El Paso County
# Ector County {'Retail & recreation': -44, 'Grocery & pharmacy': -16, 'Transit stations': -17, 'Workplace': -30, 'Residential': 13}
# El Paso County {'Retail & recreation': -53, 'Grocery & pharmacy': -23, 'Parks': -78, 'Transit stations': -44, 'Workplace': -39, 'Residential': 15}
# 11
# {'Ector County': {'Retail & recreation': -44, 'Grocery & pharmacy': -16, 'Transit stations': -17, 'Workplace': -30, 'Residential': 13}, 'El Paso County': {'Retail & recreation': -53, 'Grocery & pharmacy': -23, 'Parks': -78, 'Transit stations': -44, 'Workplace': -39, 'Residential': 15}}
# 11
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# 31 the page numbers
# Ellis County
# Erath County
# Ellis County {'Retail & recreation': -41, 'Grocery & pharmacy': -17, 'Parks': -20, 'Transit stations': -38, 'Workplace': -38, 'Residential': 14}
# Erath County {'Retail & recreation': -50, 'Grocery & pharmacy': -34, 'Workplace': -29}
# 9
# {'Ellis County': {'Retail & recreation': -41, 'Grocery & pharmacy': -17, 'Parks': -20, 'Transit stations': -38, 'Workplace': -38, 'Residential': 14}, 'Erath County': {'Retail & recreation': -50, 'Grocery & pharmacy': -34, 'Workplace': -29}}
# 9
# 32 the page numbers
# 32 the page numbers
# 32 the page numbers
# 32 the page numbers
# 32 the page numbers
# 32 the page numbers
# 32 the page numbers
# 32 the page numbers
# 32 the page numbers
# Falls County
# Fannin County
# Falls County {'Retail & recreation': -16, 'Grocery & pharmacy': -10}
# Fannin County {'Retail & recreation': -27, 'Grocery & pharmacy': -2, 'Workplace': -29}
# 5
# {'Falls County': {'Retail & recreation': -16, 'Grocery & pharmacy': -10}, 'Fannin County': {'Retail & recreation': -27, 'Grocery & pharmacy': -2, 'Workplace': -29}}
# 5
# 33 the page numbers
# 33 the page numbers
# 33 the page numbers
# 33 the page numbers
# 33 the page numbers
# Fayette County
# Floyd County
# Fayette County {'Retail & recreation': -49, 'Grocery & pharmacy': -31, 'Transit stations': -41, 'Workplace': -28}
# Floyd County {}
# 4
# {'Fayette County': {'Retail & recreation': -49, 'Grocery & pharmacy': -31, 'Transit stations': -41, 'Workplace': -28}, 'Floyd County': {}}
# 4
# 34 the page numbers
# 34 the page numbers
# 34 the page numbers
# 34 the page numbers
# Fort Bend County
# Franklin County
# Fort Bend County {'Retail & recreation': -50, 'Grocery & pharmacy': -25, 'Parks': -22, 'Transit stations': -37, 'Workplace': -41, 'Residential': 16}
# Franklin County {'Retail & recreation': -43, 'Grocery & pharmacy': -2, 'Transit stations': -27}
# 9
# {'Fort Bend County': {'Retail & recreation': -50, 'Grocery & pharmacy': -25, 'Parks': -22, 'Transit stations': -37, 'Workplace': -41, 'Residential': 16}, 'Franklin County': {'Retail & recreation': -43, 'Grocery & pharmacy': -2, 'Transit stations': -27}}
# 8
# 35 the page numbers
# 35 the page numbers
# 35 the page numbers
# 35 the page numbers
# 35 the page numbers
# 35 the page numbers
# 35 the page numbers
# 35 the page numbers
# Freestone County
# Frio County
# Freestone County {'Retail & recreation': -54, 'Grocery & pharmacy': -13, 'Transit stations': -48, 'Workplace': -24}
# Frio County {'Retail & recreation': -25, 'Grocery & pharmacy': -30, 'Workplace': -17}
# 7
# {'Freestone County': {'Retail & recreation': -54, 'Grocery & pharmacy': -13, 'Transit stations': -48, 'Workplace': -24}, 'Frio County': {'Retail & recreation': -25, 'Grocery & pharmacy': -30, 'Workplace': -17}}
# 7
# 36 the page numbers
# 36 the page numbers
# 36 the page numbers
# 36 the page numbers
# 36 the page numbers
# 36 the page numbers
# 36 the page numbers
# Gaines County
# Galveston County
# Gaines County {'Retail & recreation': -33, 'Grocery & pharmacy': -8, 'Workplace': -31}
# Galveston County {'Retail & recreation': -46, 'Grocery & pharmacy': -16, 'Parks': -48, 'Transit stations': -59, 'Workplace': -39, 'Residential': 13}
# 9
# {'Gaines County': {'Retail & recreation': -33, 'Grocery & pharmacy': -8, 'Workplace': -31}, 'Galveston County': {'Retail & recreation': -46, 'Grocery & pharmacy': -16, 'Parks': -48, 'Transit stations': -59, 'Workplace': -39, 'Residential': 13}}
# 9
# 37 the page numbers
# 37 the page numbers
# 37 the page numbers
# 37 the page numbers
# 37 the page numbers
# 37 the page numbers
# 37 the page numbers
# 37 the page numbers
# 37 the page numbers
# Garza County
# Gillespie County
# Garza County {'Grocery & pharmacy': -28}
# Gillespie County {'Retail & recreation': -60, 'Grocery & pharmacy': -32, 'Workplace': -45}
# 4
# {'Garza County': {'Grocery & pharmacy': -28}, 'Gillespie County': {'Retail & recreation': -60, 'Grocery & pharmacy': -32, 'Workplace': -45}}
# 4
# 38 the page numbers
# 38 the page numbers
# 38 the page numbers
# 38 the page numbers
# Goliad County
# Gonzales County
# Goliad County {}
# Gonzales County {'Retail & recreation': -32, 'Grocery & pharmacy': -24, 'Workplace': -20}
# 3
# {'Goliad County': {}, 'Gonzales County': {'Retail & recreation': -32, 'Grocery & pharmacy': -24, 'Workplace': -20}}
# 3
# 39 the page numbers
# 39 the page numbers
# 39 the page numbers
# Gray County
# Grayson County
# Gray County {'Retail & recreation': -47, 'Grocery & pharmacy': -27, 'Workplace': -35}
# Grayson County {'Retail & recreation': -41, 'Grocery & pharmacy': -14, 'Parks': -8, 'Workplace': -29, 'Residential': 11}
# 8
# {'Gray County': {'Retail & recreation': -47, 'Grocery & pharmacy': -27, 'Workplace': -35}, 'Grayson County': {'Retail & recreation': -41, 'Grocery & pharmacy': -14, 'Parks': -8, 'Workplace': -29, 'Residential': 11}}
# 8
# 40 the page numbers
# 40 the page numbers
# 40 the page numbers
# 40 the page numbers
# 40 the page numbers
# 40 the page numbers
# 40 the page numbers
# 40 the page numbers
# Gregg County
# Grimes County
# Gregg County {'Retail & recreation': -46, 'Grocery & pharmacy': -15, 'Parks': -25, 'Workplace': -34, 'Residential': 11}
# Grimes County {'Retail & recreation': -28, 'Grocery & pharmacy': -5, 'Workplace': -29}
# 8
# {'Gregg County': {'Retail & recreation': -46, 'Grocery & pharmacy': -15, 'Parks': -25, 'Workplace': -34, 'Residential': 11}, 'Grimes County': {'Retail & recreation': -28, 'Grocery & pharmacy': -5, 'Workplace': -29}}
# 8
# 41 the page numbers
# 41 the page numbers
# 41 the page numbers
# 41 the page numbers
# 41 the page numbers
# 41 the page numbers
# 41 the page numbers
# 41 the page numbers
# Guadalupe County
# Hale County
# Guadalupe County {'Retail & recreation': -41, 'Grocery & pharmacy': -24, 'Transit stations': -32, 'Workplace': -37, 'Residential': 13}
# Hale County {'Retail & recreation': -39, 'Grocery & pharmacy': -18, 'Workplace': -32}
# 8
# {'Guadalupe County': {'Retail & recreation': -41, 'Grocery & pharmacy': -24, 'Transit stations': -32, 'Workplace': -37, 'Residential': 13}, 'Hale County': {'Retail & recreation': -39, 'Grocery & pharmacy': -18, 'Workplace': -32}}
# 8
# 42 the page numbers
# 42 the page numbers
# 42 the page numbers
# 42 the page numbers
# 42 the page numbers
# 42 the page numbers
# 42 the page numbers
# 42 the page numbers
# Hall County
# Hamilton County
# Hall County {}
# Hamilton County {'Retail & recreation': -54, 'Grocery & pharmacy': -35}
# 2
# {'Hall County': {}, 'Hamilton County': {'Retail & recreation': -54, 'Grocery & pharmacy': -35}}
# 2
# 43 the page numbers
# 43 the page numbers
# Hardeman County
# Hardin County
# Hardeman County {'Transit stations': -25}
# Hardin County {'Retail & recreation': -39, 'Grocery & pharmacy': -10, 'Workplace': -36}
# 4
# {'Hardeman County': {'Transit stations': -25}, 'Hardin County': {'Retail & recreation': -39, 'Grocery & pharmacy': -10, 'Workplace': -36}}
# 4
# 44 the page numbers
# 44 the page numbers
# 44 the page numbers
# 44 the page numbers
# Harris County
# Harrison County
# Harris County {'Retail & recreation': -46, 'Grocery & pharmacy': -20, 'Parks': -38, 'Transit stations': -62, 'Workplace': -40, 'Residential': 14}
# Harrison County {'Retail & recreation': -38, 'Grocery & pharmacy': -7, 'Parks': -36, 'Workplace': -36}
# 10
# {'Harris County': {'Retail & recreation': -46, 'Grocery & pharmacy': -20, 'Parks': -38, 'Transit stations': -62, 'Workplace': -40, 'Residential': 14}, 'Harrison County': {'Retail & recreation': -38, 'Grocery & pharmacy': -7, 'Parks': -36, 'Workplace': -36}}
# 9
# 45 the page numbers
# 45 the page numbers
# 45 the page numbers
# 45 the page numbers
# 45 the page numbers
# 45 the page numbers
# 45 the page numbers
# 45 the page numbers
# 45 the page numbers
# Hartley County
# Haskell County
# Hartley County {}
# Haskell County {'Retail & recreation': -44, 'Grocery & pharmacy': -34}
# 2
# {'Hartley County': {}, 'Haskell County': {'Retail & recreation': -44, 'Grocery & pharmacy': -34}}
# 2
# 46 the page numbers
# 46 the page numbers
# Hays County
# Henderson County
# Hays County {'Retail & recreation': -50, 'Grocery & pharmacy': -25, 'Parks': -45, 'Workplace': -39, 'Residential': 14}
# Henderson County {'Retail & recreation': -39, 'Grocery & pharmacy': -7, 'Workplace': -35, 'Residential': 13}
# 9
# {'Hays County': {'Retail & recreation': -50, 'Grocery & pharmacy': -25, 'Parks': -45, 'Workplace': -39, 'Residential': 14}, 'Henderson County': {'Retail & recreation': -39, 'Grocery & pharmacy': -7, 'Workplace': -35, 'Residential': 13}}
# 9
# 47 the page numbers
# 47 the page numbers
# 47 the page numbers
# 47 the page numbers
# 47 the page numbers
# 47 the page numbers
# 47 the page numbers
# 47 the page numbers
# 47 the page numbers
# Hidalgo County
# Hill County
# Hidalgo County {'Retail & recreation': -64, 'Grocery & pharmacy': -43, 'Parks': -78, 'Transit stations': -68, 'Workplace': -44, 'Residential': 18}
# Hill County {'Retail & recreation': -43, 'Grocery & pharmacy': -17, 'Transit stations': -47, 'Workplace': -30}
# 10
# {'Hidalgo County': {'Retail & recreation': -64, 'Grocery & pharmacy': -43, 'Parks': -78, 'Transit stations': -68, 'Workplace': -44, 'Residential': 18}, 'Hill County': {'Retail & recreation': -43, 'Grocery & pharmacy': -17, 'Transit stations': -47, 'Workplace': -30}}
# 10
# 48 the page numbers
# 48 the page numbers
# 48 the page numbers
# 48 the page numbers
# 48 the page numbers
# 48 the page numbers
# 48 the page numbers
# 48 the page numbers
# 48 the page numbers
# 48 the page numbers
# Hockley County
# Hood County
# Hockley County {'Retail & recreation': -33, 'Grocery & pharmacy': -22, 'Workplace': -27}
# Hood County {'Retail & recreation': -47, 'Grocery & pharmacy': 13, 'Workplace': -33}
# 6
# {'Hockley County': {'Retail & recreation': -33, 'Grocery & pharmacy': -22, 'Workplace': -27}, 'Hood County': {'Retail & recreation': -47, 'Grocery & pharmacy': 13, 'Workplace': -33}}
# 6
# 49 the page numbers
# 49 the page numbers
# 49 the page numbers
# 49 the page numbers
# 49 the page numbers
# 49 the page numbers
# Hopkins County
# Houston County
# Hopkins County {'Retail & recreation': -44, 'Grocery & pharmacy': 0, 'Transit stations': -33, 'Workplace': -31}
# Houston County {'Retail & recreation': -30, 'Grocery & pharmacy': 4, 'Workplace': -27}
# 7
# {'Hopkins County': {'Retail & recreation': -44, 'Grocery & pharmacy': 0, 'Transit stations': -33, 'Workplace': -31}, 'Houston County': {'Retail & recreation': -30, 'Grocery & pharmacy': 4, 'Workplace': -27}}
# 7
# 50 the page numbers
# 50 the page numbers
# 50 the page numbers
# 50 the page numbers
# 50 the page numbers
# 50 the page numbers
# 50 the page numbers
# Howard County
# Hunt County
# Howard County {'Retail & recreation': -41, 'Grocery & pharmacy': -24, 'Transit stations': -38, 'Workplace': -27}
# Hunt County {'Retail & recreation': -41, 'Grocery & pharmacy': -17, 'Transit stations': -31, 'Workplace': -32, 'Residential': 11}
# 9
# {'Howard County': {'Retail & recreation': -41, 'Grocery & pharmacy': -24, 'Transit stations': -38, 'Workplace': -27}, 'Hunt County': {'Retail & recreation': -41, 'Grocery & pharmacy': -17, 'Transit stations': -31, 'Workplace': -32, 'Residential': 11}}
# 9
# 51 the page numbers
# 51 the page numbers
# 51 the page numbers
# 51 the page numbers
# 51 the page numbers
# 51 the page numbers
# 51 the page numbers
# 51 the page numbers
# 51 the page numbers
# Hutchinson County
# Jack County
# Hutchinson County {'Retail & recreation': -31, 'Grocery & pharmacy': -17, 'Workplace': -31}
# Jack County {}
# 3
# {'Hutchinson County': {'Retail & recreation': -31, 'Grocery & pharmacy': -17, 'Workplace': -31}, 'Jack County': {}}
# 3
# 52 the page numbers
# 52 the page numbers
# 52 the page numbers
# Jackson County
# Jasper County
# Jackson County {'Retail & recreation': -35, 'Grocery & pharmacy': -16, 'Transit stations': -52}
# Jasper County {'Retail & recreation': -38, 'Grocery & pharmacy': -22, 'Workplace': -27}
# 6
# {'Jackson County': {'Retail & recreation': -35, 'Grocery & pharmacy': -16, 'Transit stations': -52}, 'Jasper County': {'Retail & recreation': -38, 'Grocery & pharmacy': -22, 'Workplace': -27}}
# 6
# 53 the page numbers
# 53 the page numbers
# 53 the page numbers
# 53 the page numbers
# 53 the page numbers
# 53 the page numbers
# Jefferson County
# Jim Hogg County
# Jefferson County {'Retail & recreation': -47, 'Grocery & pharmacy': -19, 'Parks': -13, 'Transit stations': -39, 'Workplace': -35, 'Residential': 12}
# Jim Hogg County {'Grocery & pharmacy': -47}
# 7
# {'Jefferson County': {'Retail & recreation': -47, 'Grocery & pharmacy': -19, 'Parks': -13, 'Transit stations': -39, 'Workplace': -35, 'Residential': 12}, 'Jim Hogg County': {'Grocery & pharmacy': -47}}
# 6
# 54 the page numbers
# 54 the page numbers
# 54 the page numbers
# 54 the page numbers
# 54 the page numbers
# 54 the page numbers
# Jim Wells County
# Johnson County
# Jim Wells County {'Retail & recreation': -38, 'Grocery & pharmacy': -19, 'Workplace': -30}
# Johnson County {'Retail & recreation': -41, 'Grocery & pharmacy': -22, 'Parks': -24, 'Workplace': -36, 'Residential': 13}
# 8
# {'Jim Wells County': {'Retail & recreation': -38, 'Grocery & pharmacy': -19, 'Workplace': -30}, 'Johnson County': {'Retail & recreation': -41, 'Grocery & pharmacy': -22, 'Parks': -24, 'Workplace': -36, 'Residential': 13}}
# 7
# 55 the page numbers
# 55 the page numbers
# 55 the page numbers
# 55 the page numbers
# 55 the page numbers
# 55 the page numbers
# 55 the page numbers
# Jones County
# Karnes County
# Jones County {'Grocery & pharmacy': -11, 'Workplace': -27}
# Karnes County {'Retail & recreation': -23, 'Grocery & pharmacy': -22}
# 4
# {'Jones County': {'Grocery & pharmacy': -11, 'Workplace': -27}, 'Karnes County': {'Retail & recreation': -23, 'Grocery & pharmacy': -22}}
# 3
# 56 the page numbers
# 56 the page numbers
# 56 the page numbers
# Kaufman County
# Kendall County
# Kaufman County {'Retail & recreation': -53, 'Grocery & pharmacy': -25, 'Transit stations': -29, 'Workplace': -39, 'Residential': 13}
# Kendall County {'Retail & recreation': -48, 'Grocery & pharmacy': -33, 'Transit stations': -46, 'Workplace': -41}
# 9
# {'Kaufman County': {'Retail & recreation': -53, 'Grocery & pharmacy': -25, 'Transit stations': -29, 'Workplace': -39, 'Residential': 13}, 'Kendall County': {'Retail & recreation': -48, 'Grocery & pharmacy': -33, 'Transit stations': -46, 'Workplace': -41}}
# 9
# 57 the page numbers
# 57 the page numbers
# 57 the page numbers
# 57 the page numbers
# 57 the page numbers
# 57 the page numbers
# 57 the page numbers
# 57 the page numbers
# 57 the page numbers
# Kerr County
# Kimble County
# Kerr County {'Retail & recreation': -45, 'Grocery & pharmacy': -28, 'Workplace': -31}
# Kimble County {'Retail & recreation': -51, 'Transit stations': -32}
# 5
# {'Kerr County': {'Retail & recreation': -45, 'Grocery & pharmacy': -28, 'Workplace': -31}, 'Kimble County': {'Retail & recreation': -51, 'Transit stations': -32}}
# 4
# 58 the page numbers
# 58 the page numbers
# 58 the page numbers
# 58 the page numbers
# Kleberg County
# La Salle County
# Kleberg County {'Retail & recreation': -41, 'Grocery & pharmacy': -35, 'Transit stations': -53, 'Workplace': -26}
# La Salle County {'Retail & recreation': -65, 'Grocery & pharmacy': -26, 'Transit stations': -45}
# 7
# {'Kleberg County': {'Retail & recreation': -41, 'Grocery & pharmacy': -35, 'Transit stations': -53, 'Workplace': -26}, 'La Salle County': {'Retail & recreation': -65, 'Grocery & pharmacy': -26, 'Transit stations': -45}}
# 6
# 59 the page numbers
# 59 the page numbers
# 59 the page numbers
# 59 the page numbers
# 59 the page numbers
# 59 the page numbers
# Lamar County
# Lamb County
# Lamar County {'Retail & recreation': -39, 'Grocery & pharmacy': -7, 'Workplace': -17}
# Lamb County {'Retail & recreation': -19, 'Grocery & pharmacy': -11, 'Workplace': -24}
# 6
# {'Lamar County': {'Retail & recreation': -39, 'Grocery & pharmacy': -7, 'Workplace': -17}, 'Lamb County': {'Retail & recreation': -19, 'Grocery & pharmacy': -11, 'Workplace': -24}}
# 4
# 60 the page numbers
# 60 the page numbers
# 60 the page numbers
# 60 the page numbers
# Lampasas County
# Lavaca County
# Lampasas County {'Retail & recreation': -42, 'Grocery & pharmacy': -31, 'Workplace': -38}
# Lavaca County {'Retail & recreation': -35, 'Grocery & pharmacy': -16}
# 5
# {'Lampasas County': {'Retail & recreation': -42, 'Grocery & pharmacy': -31, 'Workplace': -38}, 'Lavaca County': {'Retail & recreation': -35, 'Grocery & pharmacy': -16}}
# 4
# 61 the page numbers
# 61 the page numbers
# 61 the page numbers
# 61 the page numbers
# Lee County
# Leon County
# Lee County {'Retail & recreation': -42, 'Grocery & pharmacy': -41}
# Leon County {'Retail & recreation': -71, 'Grocery & pharmacy': -40, 'Transit stations': -36}
# 5
# {'Lee County': {'Retail & recreation': -42, 'Grocery & pharmacy': -41}, 'Leon County': {'Retail & recreation': -71, 'Grocery & pharmacy': -40, 'Transit stations': -36}}
# 5
# 62 the page numbers
# 62 the page numbers
# 62 the page numbers
# 62 the page numbers
# 62 the page numbers
# Liberty County
# Limestone County
# Liberty County {'Retail & recreation': -42, 'Grocery & pharmacy': 0, 'Transit stations': -30, 'Workplace': -28, 'Residential': 12}
# Limestone County {'Retail & recreation': -36, 'Grocery & pharmacy': -23, 'Workplace': -31}
# 8
# {'Liberty County': {'Retail & recreation': -42, 'Grocery & pharmacy': 0, 'Transit stations': -30, 'Workplace': -28, 'Residential': 12}, 'Limestone County': {'Retail & recreation': -36, 'Grocery & pharmacy': -23, 'Workplace': -31}}
# 8
# 63 the page numbers
# 63 the page numbers
# 63 the page numbers
# 63 the page numbers
# 63 the page numbers
# 63 the page numbers
# 63 the page numbers
# 63 the page numbers
# Live Oak County
# Llano County
# Live Oak County {'Retail & recreation': -73, 'Grocery & pharmacy': -36, 'Transit stations': -56}
# Llano County {'Retail & recreation': -38, 'Grocery & pharmacy': -24, 'Workplace': -34}
# 6
# {'Live Oak County': {'Retail & recreation': -73, 'Grocery & pharmacy': -36, 'Transit stations': -56}, 'Llano County': {'Retail & recreation': -38, 'Grocery & pharmacy': -24, 'Workplace': -34}}
# 6
# 64 the page numbers
# 64 the page numbers
# 64 the page numbers
# 64 the page numbers
# 64 the page numbers
# 64 the page numbers
# Loving County
# Lubbock County
# Loving County {}
# Lubbock County {'Retail & recreation': -44, 'Grocery & pharmacy': -19, 'Parks': -14, 'Transit stations': -46, 'Workplace': -33, 'Residential': 12}
# 6
# {'Loving County': {}, 'Lubbock County': {'Retail & recreation': -44, 'Grocery & pharmacy': -19, 'Parks': -14, 'Transit stations': -46, 'Workplace': -33, 'Residential': 12}}
# 6
# 65 the page numbers
# 65 the page numbers
# 65 the page numbers
# 65 the page numbers
# 65 the page numbers
# 65 the page numbers
# Lynn County
# Madison County
# Lynn County {}
# Madison County {'Retail & recreation': -43, 'Grocery & pharmacy': -68}
# 2
# {'Lynn County': {}, 'Madison County': {'Retail & recreation': -43, 'Grocery & pharmacy': -68}}
# 2
# 66 the page numbers
# 66 the page numbers
# Marion County
# Martin County
# Marion County {'Retail & recreation': -45, 'Grocery & pharmacy': -4}
# Martin County {'Grocery & pharmacy': -14}
# 3
# {'Marion County': {'Retail & recreation': -45, 'Grocery & pharmacy': -4}, 'Martin County': {'Grocery & pharmacy': -14}}
# 2
# 67 the page numbers
# 67 the page numbers
# Matagorda County
# Maverick County
# Matagorda County {'Retail & recreation': -46, 'Grocery & pharmacy': -26, 'Workplace': -13}
# Maverick County {'Retail & recreation': -61, 'Grocery & pharmacy': -41, 'Transit stations': -68, 'Workplace': -41}
# 7
# {'Matagorda County': {'Retail & recreation': -46, 'Grocery & pharmacy': -26, 'Workplace': -13}, 'Maverick County': {'Retail & recreation': -61, 'Grocery & pharmacy': -41, 'Transit stations': -68, 'Workplace': -41}}
# 7
# 68 the page numbers
# 68 the page numbers
# 68 the page numbers
# 68 the page numbers
# 68 the page numbers
# 68 the page numbers
# 68 the page numbers
# McCulloch County
# McLennan County
# McCulloch County {'Retail & recreation': -37, 'Grocery & pharmacy': -22}
# McLennan County {'Retail & recreation': -49, 'Grocery & pharmacy': -23, 'Parks': -33, 'Transit stations': -36, 'Workplace': -36, 'Residential': 12}
# 8
# {'McCulloch County': {'Retail & recreation': -37, 'Grocery & pharmacy': -22}, 'McLennan County': {'Retail & recreation': -49, 'Grocery & pharmacy': -23, 'Parks': -33, 'Transit stations': -36, 'Workplace': -36, 'Residential': 12}}
# 7
# 69 the page numbers
# 69 the page numbers
# 69 the page numbers
# 69 the page numbers
# 69 the page numbers
# 69 the page numbers
# 69 the page numbers
# McMullen County
# Medina County
# McMullen County {}
# Medina County {'Retail & recreation': -27, 'Grocery & pharmacy': -12, 'Transit stations': -38, 'Workplace': -33}
# 4
# {'McMullen County': {}, 'Medina County': {'Retail & recreation': -27, 'Grocery & pharmacy': -12, 'Transit stations': -38, 'Workplace': -33}}
# 4
# 70 the page numbers
# 70 the page numbers
# 70 the page numbers
# 70 the page numbers
# Midland County
# Milam County
# Midland County {'Retail & recreation': -48, 'Grocery & pharmacy': -20, 'Parks': -41, 'Transit stations': -31, 'Workplace': -28, 'Residential': 13}
# Milam County {'Retail & recreation': -39, 'Grocery & pharmacy': -20, 'Workplace': -35}
# 9
# {'Midland County': {'Retail & recreation': -48, 'Grocery & pharmacy': -20, 'Parks': -41, 'Transit stations': -31, 'Workplace': -28, 'Residential': 13}, 'Milam County': {'Retail & recreation': -39, 'Grocery & pharmacy': -20, 'Workplace': -35}}
# 9
# 71 the page numbers
# 71 the page numbers
# 71 the page numbers
# 71 the page numbers
# 71 the page numbers
# 71 the page numbers
# 71 the page numbers
# 71 the page numbers
# 71 the page numbers
# Mitchell County
# Montague County
# Mitchell County {'Grocery & pharmacy': -23}
# Montague County {'Retail & recreation': -18, 'Grocery & pharmacy': -33, 'Workplace': -35}
# 4
# {'Mitchell County': {'Grocery & pharmacy': -23}, 'Montague County': {'Retail & recreation': -18, 'Grocery & pharmacy': -33, 'Workplace': -35}}
# 4
# 72 the page numbers
# 72 the page numbers
# 72 the page numbers
# 72 the page numbers
# Montgomery County
# Moore County
# Montgomery County {'Retail & recreation': -48, 'Grocery & pharmacy': -21, 'Parks': -33, 'Transit stations': -35, 'Workplace': -39, 'Residential': 13}
# Moore County {'Retail & recreation': -36, 'Grocery & pharmacy': -17, 'Workplace': -18}
# 9
# {'Montgomery County': {'Retail & recreation': -48, 'Grocery & pharmacy': -21, 'Parks': -33, 'Transit stations': -35, 'Workplace': -39, 'Residential': 13}, 'Moore County': {'Retail & recreation': -36, 'Grocery & pharmacy': -17, 'Workplace': -18}}
# 9
# 73 the page numbers
# 73 the page numbers
# 73 the page numbers
# 73 the page numbers
# 73 the page numbers
# 73 the page numbers
# 73 the page numbers
# 73 the page numbers
# 73 the page numbers
# Morris County
# Nacogdoches County
# Morris County {'Retail & recreation': -32, 'Grocery & pharmacy': -10}
# Nacogdoches County {'Retail & recreation': -53, 'Grocery & pharmacy': -24, 'Transit stations': -52, 'Workplace': -33}
# 6
# {'Morris County': {'Retail & recreation': -32, 'Grocery & pharmacy': -10}, 'Nacogdoches County': {'Retail & recreation': -53, 'Grocery & pharmacy': -24, 'Transit stations': -52, 'Workplace': -33}}
# 5
# 74 the page numbers
# 74 the page numbers
# 74 the page numbers
# 74 the page numbers
# 74 the page numbers
# Navarro County
# Newton County
# Navarro County {'Retail & recreation': -55, 'Grocery & pharmacy': 10, 'Transit stations': -56, 'Workplace': -32}
# Newton County {}
# 4
# {'Navarro County': {'Retail & recreation': -55, 'Grocery & pharmacy': 10, 'Transit stations': -56, 'Workplace': -32}, 'Newton County': {}}
# 3
# 75 the page numbers
# 75 the page numbers
# 75 the page numbers
# Nolan County
# Nueces County
# Nolan County {'Retail & recreation': -40, 'Grocery & pharmacy': -12, 'Transit stations': -36, 'Workplace': -19}
# Nueces County {'Retail & recreation': -45, 'Grocery & pharmacy': -22, 'Parks': -38, 'Transit stations': -43, 'Workplace': -37, 'Residential': 13}
# 10
# {'Nolan County': {'Retail & recreation': -40, 'Grocery & pharmacy': -12, 'Transit stations': -36, 'Workplace': -19}, 'Nueces County': {'Retail & recreation': -45, 'Grocery & pharmacy': -22, 'Parks': -38, 'Transit stations': -43, 'Workplace': -37, 'Residential': 13}}
# 10
# 76 the page numbers
# 76 the page numbers
# 76 the page numbers
# 76 the page numbers
# 76 the page numbers
# 76 the page numbers
# 76 the page numbers
# 76 the page numbers
# 76 the page numbers
# 76 the page numbers
# Ochiltree County
# Oldham County
# Ochiltree County {'Retail & recreation': -41, 'Grocery & pharmacy': -14}
# Oldham County {'Transit stations': -16}
# 3
# {'Ochiltree County': {'Retail & recreation': -41, 'Grocery & pharmacy': -14}, 'Oldham County': {'Transit stations': -16}}
# 2
# 77 the page numbers
# 77 the page numbers
# Orange County
# Palo Pinto County
# Orange County {'Retail & recreation': -37, 'Grocery & pharmacy': -11, 'Parks': -36, 'Transit stations': -44, 'Workplace': -33, 'Residential': 15}
# Palo Pinto County {'Retail & recreation': -31, 'Grocery & pharmacy': -3, 'Workplace': -28}
# 9
# {'Orange County': {'Retail & recreation': -37, 'Grocery & pharmacy': -11, 'Parks': -36, 'Transit stations': -44, 'Workplace': -33, 'Residential': 15}, 'Palo Pinto County': {'Retail & recreation': -31, 'Grocery & pharmacy': -3, 'Workplace': -28}}
# 9
# 78 the page numbers
# 78 the page numbers
# 78 the page numbers
# 78 the page numbers
# 78 the page numbers
# 78 the page numbers
# 78 the page numbers
# 78 the page numbers
# 78 the page numbers
# Panola County
# Parker County
# Panola County {'Retail & recreation': -38, 'Grocery & pharmacy': -19, 'Transit stations': -34, 'Workplace': -41}
# Parker County {'Retail & recreation': -45, 'Grocery & pharmacy': -15, 'Parks': -30, 'Transit stations': -34, 'Workplace': -38, 'Residential': 12}
# 10
# {'Panola County': {'Retail & recreation': -38, 'Grocery & pharmacy': -19, 'Transit stations': -34, 'Workplace': -41}, 'Parker County': {'Retail & recreation': -45, 'Grocery & pharmacy': -15, 'Parks': -30, 'Transit stations': -34, 'Workplace': -38, 'Residential': 12}}
# 10
# 79 the page numbers
# 79 the page numbers
# 79 the page numbers
# 79 the page numbers
# 79 the page numbers
# 79 the page numbers
# 79 the page numbers
# 79 the page numbers
# 79 the page numbers
# 79 the page numbers
# Parmer County
# Pecos County
# Parmer County {'Grocery & pharmacy': -4}
# Pecos County {'Retail & recreation': -39, 'Grocery & pharmacy': -28, 'Transit stations': -29, 'Workplace': -24}
# 5
# {'Parmer County': {'Grocery & pharmacy': -4}, 'Pecos County': {'Retail & recreation': -39, 'Grocery & pharmacy': -28, 'Transit stations': -29, 'Workplace': -24}}
# 4
# 80 the page numbers
# 80 the page numbers
# 80 the page numbers
# 80 the page numbers
# Polk County
# Potter County
# Polk County {'Retail & recreation': -39, 'Grocery & pharmacy': -16, 'Workplace': -35}
# Potter County {'Retail & recreation': -48, 'Grocery & pharmacy': -16, 'Parks': -23, 'Transit stations': -30, 'Workplace': -31, 'Residential': 10}
# 9
# {'Polk County': {'Retail & recreation': -39, 'Grocery & pharmacy': -16, 'Workplace': -35}, 'Potter County': {'Retail & recreation': -48, 'Grocery & pharmacy': -16, 'Parks': -23, 'Transit stations': -30, 'Workplace': -31, 'Residential': 10}}
# 9
# 81 the page numbers
# 81 the page numbers
# 81 the page numbers
# 81 the page numbers
# 81 the page numbers
# 81 the page numbers
# 81 the page numbers
# 81 the page numbers
# 81 the page numbers
# Presidio County
# Rains County
# Presidio County {'Grocery & pharmacy': -42}
# Rains County {'Retail & recreation': -53, 'Grocery & pharmacy': -25}
# 3
# {'Presidio County': {'Grocery & pharmacy': -42}, 'Rains County': {'Retail & recreation': -53, 'Grocery & pharmacy': -25}}
# 3
# 82 the page numbers
# 82 the page numbers
# 82 the page numbers
# Randall County
# Reagan County
# Randall County {'Retail & recreation': -37, 'Grocery & pharmacy': -19, 'Workplace': -36, 'Residential': 11}
# Reagan County {'Grocery & pharmacy': -22}
# 5
# {'Randall County': {'Retail & recreation': -37, 'Grocery & pharmacy': -19, 'Workplace': -36, 'Residential': 11}, 'Reagan County': {'Grocery & pharmacy': -22}}
# 5
# 83 the page numbers
# 83 the page numbers
# 83 the page numbers
# 83 the page numbers
# 83 the page numbers
# Real County
# Red River County
# Real County {}
# Red River County {}
# 0
# {'Real County': {}, 'Red River County': {}}
# 0
# Reeves County
# Refugio County
# Reeves County {'Retail & recreation': -39, 'Grocery & pharmacy': -16, 'Transit stations': -20, 'Workplace': -10}
# Refugio County {'Retail & recreation': -69, 'Grocery & pharmacy': -44, 'Transit stations': -52}
# 7
# {'Reeves County': {'Retail & recreation': -39, 'Grocery & pharmacy': -16, 'Transit stations': -20, 'Workplace': -10}, 'Refugio County': {'Retail & recreation': -69, 'Grocery & pharmacy': -44, 'Transit stations': -52}}
# 7
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# Robertson County
# Rockwall County
# Robertson County {'Retail & recreation': -52, 'Grocery & pharmacy': -25, 'Transit stations': -37}
# Rockwall County {'Retail & recreation': -47, 'Grocery & pharmacy': -27, 'Transit stations': -26, 'Workplace': -40}
# 7
# {'Robertson County': {'Retail & recreation': -52, 'Grocery & pharmacy': -25, 'Transit stations': -37}, 'Rockwall County': {'Retail & recreation': -47, 'Grocery & pharmacy': -27, 'Transit stations': -26, 'Workplace': -40}}
# 7
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# Runnels County
# Rusk County
# Runnels County {'Retail & recreation': -25, 'Grocery & pharmacy': -17}
# Rusk County {'Retail & recreation': -30, 'Grocery & pharmacy': -7, 'Workplace': -32}
# 5
# {'Runnels County': {'Retail & recreation': -25, 'Grocery & pharmacy': -17}, 'Rusk County': {'Retail & recreation': -30, 'Grocery & pharmacy': -7, 'Workplace': -32}}
# 5
# 87 the page numbers
# 87 the page numbers
# 87 the page numbers
# 87 the page numbers
# 87 the page numbers
# Sabine County
# San Augustine County
# Sabine County {'Grocery & pharmacy': -2}
# San Augustine County {}
# 1
# {'Sabine County': {'Grocery & pharmacy': -2}, 'San Augustine County': {}}
# 0
# San Jacinto County
# San Patricio County
# San Jacinto County {'Grocery & pharmacy': 3, 'Workplace': -30}
# San Patricio County {'Retail & recreation': -38, 'Grocery & pharmacy': -22, 'Transit stations': -51, 'Workplace': -24, 'Residential': 17}
# 7
# {'San Jacinto County': {'Grocery & pharmacy': 3, 'Workplace': -30}, 'San Patricio County': {'Retail & recreation': -38, 'Grocery & pharmacy': -22, 'Transit stations': -51, 'Workplace': -24, 'Residential': 17}}
# 6
# 89 the page numbers
# 89 the page numbers
# 89 the page numbers
# 89 the page numbers
# 89 the page numbers
# 89 the page numbers
# San Saba County
# Scurry County
# San Saba County {}
# Scurry County {'Retail & recreation': -26, 'Grocery & pharmacy': -20, 'Workplace': -18}
# 3
# {'San Saba County': {}, 'Scurry County': {'Retail & recreation': -26, 'Grocery & pharmacy': -20, 'Workplace': -18}}
# 2
# 90 the page numbers
# 90 the page numbers
# Shelby County
# Sherman County
# Shelby County {'Retail & recreation': -46, 'Grocery & pharmacy': -19, 'Workplace': -32}
# Sherman County {'Transit stations': -16}
# 4
# {'Shelby County': {'Retail & recreation': -46, 'Grocery & pharmacy': -19, 'Workplace': -32}, 'Sherman County': {'Transit stations': -16}}
# 4
# 91 the page numbers
# 91 the page numbers
# 91 the page numbers
# 91 the page numbers
# Smith County
# Somervell County
# Smith County {'Retail & recreation': -47, 'Grocery & pharmacy': -18, 'Parks': -40, 'Transit stations': -40, 'Workplace': -37, 'Residential': 13}
# Somervell County {'Retail & recreation': -59}
# 7
# {'Smith County': {'Retail & recreation': -47, 'Grocery & pharmacy': -18, 'Parks': -40, 'Transit stations': -40, 'Workplace': -37, 'Residential': 13}, 'Somervell County': {'Retail & recreation': -59}}
# 7
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# Starr County
# Stephens County
# Starr County {'Retail & recreation': -54, 'Grocery & pharmacy': -37, 'Workplace': -33}
# Stephens County {'Retail & recreation': -34}
# 4
# {'Starr County': {'Retail & recreation': -54, 'Grocery & pharmacy': -37, 'Workplace': -33}, 'Stephens County': {'Retail & recreation': -34}}
# 4
# 93 the page numbers
# 93 the page numbers
# 93 the page numbers
# 93 the page numbers
# Sutton County
# Swisher County
# Sutton County {}
# Swisher County {}
# 0
# {'Sutton County': {}, 'Swisher County': {}}
# 0
# Tarrant County
# Taylor County
# Tarrant County {'Retail & recreation': -51, 'Grocery & pharmacy': -20, 'Parks': -42, 'Transit stations': -74, 'Workplace': -39, 'Residential': 14}
# Taylor County {'Retail & recreation': -43, 'Grocery & pharmacy': -21, 'Transit stations': -21, 'Workplace': -31, 'Residential': 11}
# 11
# {'Tarrant County': {'Retail & recreation': -51, 'Grocery & pharmacy': -20, 'Parks': -42, 'Transit stations': -74, 'Workplace': -39, 'Residential': 14}, 'Taylor County': {'Retail & recreation': -43, 'Grocery & pharmacy': -21, 'Transit stations': -21, 'Workplace': -31, 'Residential': 11}}
# 11
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# Terry County
# Titus County
# Terry County {'Retail & recreation': -30, 'Grocery & pharmacy': -27}
# Titus County {'Retail & recreation': -38, 'Grocery & pharmacy': -10, 'Workplace': -24}
# 5
# {'Terry County': {'Retail & recreation': -30, 'Grocery & pharmacy': -27}, 'Titus County': {'Retail & recreation': -38, 'Grocery & pharmacy': -10, 'Workplace': -24}}
# 5
# 96 the page numbers
# 96 the page numbers
# 96 the page numbers
# 96 the page numbers
# 96 the page numbers
# Tom Green County
# Travis County
# ...
# 5
# 83 the page numbers
# 83 the page numbers
# 83 the page numbers
# 83 the page numbers
# 83 the page numbers
# Real County
# Red River County
# Real County {}
# Red River County {}
# 0
# {'Real County': {}, 'Red River County': {}}
# 0
# Reeves County
# Refugio County
# Reeves County {'Retail & recreation': -39, 'Grocery & pharmacy': -16, 'Transit stations': -20, 'Workplace': -10}
# Refugio County {'Retail & recreation': -69, 'Grocery & pharmacy': -44, 'Transit stations': -52}
# 7
# {'Reeves County': {'Retail & recreation': -39, 'Grocery & pharmacy': -16, 'Transit stations': -20, 'Workplace': -10}, 'Refugio County': {'Retail & recreation': -69, 'Grocery & pharmacy': -44, 'Transit stations': -52}}
# 7
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# 85 the page numbers
# Robertson County
# Rockwall County
# Robertson County {'Retail & recreation': -52, 'Grocery & pharmacy': -25, 'Transit stations': -37}
# Rockwall County {'Retail & recreation': -47, 'Grocery & pharmacy': -27, 'Transit stations': -26, 'Workplace': -40}
# 7
# {'Robertson County': {'Retail & recreation': -52, 'Grocery & pharmacy': -25, 'Transit stations': -37}, 'Rockwall County': {'Retail & recreation': -47, 'Grocery & pharmacy': -27, 'Transit stations': -26, 'Workplace': -40}}
# 7
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# 86 the page numbers
# Runnels County
# Rusk County
# Runnels County {'Retail & recreation': -25, 'Grocery & pharmacy': -17}
# Rusk County {'Retail & recreation': -30, 'Grocery & pharmacy': -7, 'Workplace': -32}
# 5
# {'Runnels County': {'Retail & recreation': -25, 'Grocery & pharmacy': -17}, 'Rusk County': {'Retail & recreation': -30, 'Grocery & pharmacy': -7, 'Workplace': -32}}
# 5
# 87 the page numbers
# 87 the page numbers
# 87 the page numbers
# 87 the page numbers
# 87 the page numbers
# Sabine County
# San Augustine County
# Sabine County {'Grocery & pharmacy': -2}
# San Augustine County {}
# 1
# {'Sabine County': {'Grocery & pharmacy': -2}, 'San Augustine County': {}}
# 0
# San Jacinto County
# San Patricio County
# San Jacinto County {'Grocery & pharmacy': 3, 'Workplace': -30}
# San Patricio County {'Retail & recreation': -38, 'Grocery & pharmacy': -22, 'Transit stations': -51, 'Workplace': -24, 'Residential': 17}
# 7
# {'San Jacinto County': {'Grocery & pharmacy': 3, 'Workplace': -30}, 'San Patricio County': {'Retail & recreation': -38, 'Grocery & pharmacy': -22, 'Transit stations': -51, 'Workplace': -24, 'Residential': 17}}
# 6
# 89 the page numbers
# 89 the page numbers
# 89 the page numbers
# 89 the page numbers
# 89 the page numbers
# 89 the page numbers
# San Saba County
# Scurry County
# San Saba County {}
# Scurry County {'Retail & recreation': -26, 'Grocery & pharmacy': -20, 'Workplace': -18}
# 3
# {'San Saba County': {}, 'Scurry County': {'Retail & recreation': -26, 'Grocery & pharmacy': -20, 'Workplace': -18}}
# 2
# 90 the page numbers
# 90 the page numbers
# Shelby County
# Sherman County
# Shelby County {'Retail & recreation': -46, 'Grocery & pharmacy': -19, 'Workplace': -32}
# Sherman County {'Transit stations': -16}
# 4
# {'Shelby County': {'Retail & recreation': -46, 'Grocery & pharmacy': -19, 'Workplace': -32}, 'Sherman County': {'Transit stations': -16}}
# 4
# 91 the page numbers
# 91 the page numbers
# 91 the page numbers
# 91 the page numbers
# Smith County
# Somervell County
# Smith County {'Retail & recreation': -47, 'Grocery & pharmacy': -18, 'Parks': -40, 'Transit stations': -40, 'Workplace': -37, 'Residential': 13}
# Somervell County {'Retail & recreation': -59}
# 7
# {'Smith County': {'Retail & recreation': -47, 'Grocery & pharmacy': -18, 'Parks': -40, 'Transit stations': -40, 'Workplace': -37, 'Residential': 13}, 'Somervell County': {'Retail & recreation': -59}}
# 7
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# 92 the page numbers
# Starr County
# Stephens County
# Starr County {'Retail & recreation': -54, 'Grocery & pharmacy': -37, 'Workplace': -33}
# Stephens County {'Retail & recreation': -34}
# 4
# {'Starr County': {'Retail & recreation': -54, 'Grocery & pharmacy': -37, 'Workplace': -33}, 'Stephens County': {'Retail & recreation': -34}}
# 4
# 93 the page numbers
# 93 the page numbers
# 93 the page numbers
# 93 the page numbers
# Sutton County
# Swisher County
# Sutton County {}
# Swisher County {}
# 0
# {'Sutton County': {}, 'Swisher County': {}}
# 0
# Tarrant County
# Taylor County
# Tarrant County {'Retail & recreation': -51, 'Grocery & pharmacy': -20, 'Parks': -42, 'Transit stations': -74, 'Workplace': -39, 'Residential': 14}
# Taylor County {'Retail & recreation': -43, 'Grocery & pharmacy': -21, 'Transit stations': -21, 'Workplace': -31, 'Residential': 11}
# 11
# {'Tarrant County': {'Retail & recreation': -51, 'Grocery & pharmacy': -20, 'Parks': -42, 'Transit stations': -74, 'Workplace': -39, 'Residential': 14}, 'Taylor County': {'Retail & recreation': -43, 'Grocery & pharmacy': -21, 'Transit stations': -21, 'Workplace': -31, 'Residential': 11}}
# 11
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# 95 the page numbers
# Terry County
# Titus County
# Terry County {'Retail & recreation': -30, 'Grocery & pharmacy': -27}
# Titus County {'Retail & recreation': -38, 'Grocery & pharmacy': -10, 'Workplace': -24}
# 5
# {'Terry County': {'Retail & recreation': -30, 'Grocery & pharmacy': -27}, 'Titus County': {'Retail & recreation': -38, 'Grocery & pharmacy': -10, 'Workplace': -24}}
# 5
# 96 the page numbers
# 96 the page numbers
# 96 the page numbers
# 96 the page numbers
# 96 the page numbers
# Tom Green County
# Travis County
# Tom Green County {'Retail & recreation': -53, 'Grocery & pharmacy': -22, 'Workplace': -31, 'Residential': 12}
# Travis County {'Retail & recreation': -56, 'Grocery & pharmacy': -30, 'Parks': -44, 'Transit stations': -74, 'Workplace': -46, 'Residential': 16}
# 10
# {'Tom Green County': {'Retail & recreation': -53, 'Grocery & pharmacy': -22, 'Workplace': -31, 'Residential': 12}, 'Travis County': {'Retail & recreation': -56, 'Grocery & pharmacy': -30, 'Parks': -44, 'Transit stations': -74, 'Workplace': -46, 'Residential': 16}}
# 10
# 97 the page numbers
# 97 the page numbers
# 97 the page numbers
# 97 the page numbers
# 97 the page numbers
# 97 the page numbers
# 97 the page numbers
# 97 the page numbers
# 97 the page numbers
# 97 the page numbers
# Trinity County
# Tyler County
# Trinity County {'Retail & recreation': -56, 'Grocery & pharmacy': -10}
# Tyler County {'Retail & recreation': -32, 'Grocery & pharmacy': 5, 'Workplace': -32}
# 5
# {'Trinity County': {'Retail & recreation': -56, 'Grocery & pharmacy': -10}, 'Tyler County': {'Retail & recreation': -32, 'Grocery & pharmacy': 5, 'Workplace': -32}}
# 4
# 98 the page numbers
# 98 the page numbers
# 98 the page numbers
# 98 the page numbers
# Upshur County
# Upton County
# Upshur County {'Retail & recreation': -33, 'Grocery & pharmacy': 4, 'Workplace': -35}
# Upton County {'Grocery & pharmacy': -25}
# 4
# {'Upshur County': {'Retail & recreation': -33, 'Grocery & pharmacy': 4, 'Workplace': -35}, 'Upton County': {'Grocery & pharmacy': -25}}
# 4
# 99 the page numbers
# 99 the page numbers
# 99 the page numbers
# 99 the page numbers
# Uvalde County
# Val Verde County
# Uvalde County {'Retail & recreation': -44, 'Grocery & pharmacy': -36, 'Workplace': -26}
# Val Verde County {'Retail & recreation': -50, 'Grocery & pharmacy': -32, 'Workplace': -35}
# 6
# {'Uvalde County': {'Retail & recreation': -44, 'Grocery & pharmacy': -36, 'Workplace': -26}, 'Val Verde County': {'Retail & recreation': -50, 'Grocery & pharmacy': -32, 'Workplace': -35}}
# 6
# 100 the page numbers
# 100 the page numbers
# 100 the page numbers
# 100 the page numbers
# 100 the page numbers
# 100 the page numbers
# Van Zandt County
# Victoria County
# Van Zandt County {'Retail & recreation': -42, 'Grocery & pharmacy': -17, 'Transit stations': -33, 'Workplace': -34}
# Victoria County {'Retail & recreation': -50, 'Grocery & pharmacy': -27, 'Transit stations': -59, 'Workplace': -32, 'Residential': 13}
# 9
# {'Van Zandt County': {'Retail & recreation': -42, 'Grocery & pharmacy': -17, 'Transit stations': -33, 'Workplace': -34}, 'Victoria County': {'Retail & recreation': -50, 'Grocery & pharmacy': -27, 'Transit stations': -59, 'Workplace': -32, 'Residential': 13}}
# 9
# 101 the page numbers
# 101 the page numbers
# 101 the page numbers
# 101 the page numbers
# 101 the page numbers
# 101 the page numbers
# 101 the page numbers
# 101 the page numbers
# 101 the page numbers
# Walker County
# Waller County
# Walker County {'Retail & recreation': -44, 'Grocery & pharmacy': -19, 'Parks': -33, 'Transit stations': -47, 'Workplace': -34}
# Waller County {'Retail & recreation': -49, 'Grocery & pharmacy': -16, 'Transit stations': -28, 'Workplace': -37}
# 9
# {'Walker County': {'Retail & recreation': -44, 'Grocery & pharmacy': -19, 'Parks': -33, 'Transit stations': -47, 'Workplace': -34}, 'Waller County': {'Retail & recreation': -49, 'Grocery & pharmacy': -16, 'Transit stations': -28, 'Workplace': -37}}
# 9
# 102 the page numbers
# 102 the page numbers
# 102 the page numbers
# 102 the page numbers
# 102 the page numbers
# 102 the page numbers
# 102 the page numbers
# 102 the page numbers
# 102 the page numbers
# Ward County
# Washington County
# Ward County {'Retail & recreation': -33, 'Grocery & pharmacy': -17, 'Workplace': -18}
# Washington County {'Retail & recreation': -40, 'Grocery & pharmacy': -16, 'Workplace': -29}
# 6
# {'Ward County': {'Retail & recreation': -33, 'Grocery & pharmacy': -17, 'Workplace': -18}, 'Washington County': {'Retail & recreation': -40, 'Grocery & pharmacy': -16, 'Workplace': -29}}
# 6
# 103 the page numbers
# 103 the page numbers
# 103 the page numbers
# 103 the page numbers
# 103 the page numbers
# 103 the page numbers
# Webb County
# Wharton County
# Webb County {'Retail & recreation': -61, 'Grocery & pharmacy': -42, 'Parks': -72, 'Transit stations': -48, 'Workplace': -40, 'Residential': 17}
# Wharton County {'Retail & recreation': -29, 'Grocery & pharmacy': -38, 'Transit stations': -47, 'Workplace': -23}
# 10
# {'Webb County': {'Retail & recreation': -61, 'Grocery & pharmacy': -42, 'Parks': -72, 'Transit stations': -48, 'Workplace': -40, 'Residential': 17}, 'Wharton County': {'Retail & recreation': -29, 'Grocery & pharmacy': -38, 'Transit stations': -47, 'Workplace': -23}}
# 10
# 104 the page numbers
# 104 the page numbers
# 104 the page numbers
# 104 the page numbers
# 104 the page numbers
# 104 the page numbers
# 104 the page numbers
# 104 the page numbers
# 104 the page numbers
# 104 the page numbers
# Wheeler County
# Wichita County
# Wheeler County {}
# Wichita County {'Retail & recreation': -45, 'Grocery & pharmacy': -23, 'Transit stations': -20, 'Workplace': -35, 'Residential': 11}
# 5
# {'Wheeler County': {}, 'Wichita County': {'Retail & recreation': -45, 'Grocery & pharmacy': -23, 'Transit stations': -20, 'Workplace': -35, 'Residential': 11}}
# 5
# 105 the page numbers
# 105 the page numbers
# 105 the page numbers
# 105 the page numbers
# 105 the page numbers
# Wilbarger County
# Willacy County
# Wilbarger County {'Retail & recreation': -23, 'Grocery & pharmacy': -15, 'Workplace': -16}
# Willacy County {'Retail & recreation': -58, 'Grocery & pharmacy': -38, 'Workplace': -34}
# 6
# {'Wilbarger County': {'Retail & recreation': -23, 'Grocery & pharmacy': -15, 'Workplace': -16}, 'Willacy County': {'Retail & recreation': -58, 'Grocery & pharmacy': -38, 'Workplace': -34}}
# 5
# 106 the page numbers
# 106 the page numbers
# 106 the page numbers
# 106 the page numbers
# 106 the page numbers
# Williamson County
# Wilson County
# Williamson County {'Retail & recreation': -53, 'Grocery & pharmacy': -31, 'Parks': -36, 'Transit stations': -53, 'Workplace': -45, 'Residential': 15}
# Wilson County {'Retail & recreation': -35, 'Grocery & pharmacy': -52, 'Workplace': -37}
# 9
# {'Williamson County': {'Retail & recreation': -53, 'Grocery & pharmacy': -31, 'Parks': -36, 'Transit stations': -53, 'Workplace': -45, 'Residential': 15}, 'Wilson County': {'Retail & recreation': -35, 'Grocery & pharmacy': -52, 'Workplace': -37}}
# 9
# 107 the page numbers
# 107 the page numbers
# 107 the page numbers
# 107 the page numbers
# 107 the page numbers
# 107 the page numbers
# 107 the page numbers
# 107 the page numbers
# 107 the page numbers
# Winkler County
# Wise County
# Winkler County {'Retail & recreation': -30, 'Grocery & pharmacy': -25}
# Wise County {'Retail & recreation': -39, 'Grocery & pharmacy': -17, 'Transit stations': -24, 'Workplace': -37}
# 6
# {'Winkler County': {'Retail & recreation': -30, 'Grocery & pharmacy': -25}, 'Wise County': {'Retail & recreation': -39, 'Grocery & pharmacy': -17, 'Transit stations': -24, 'Workplace': -37}}
# 6
# 108 the page numbers
# 108 the page numbers
# 108 the page numbers
# 108 the page numbers
# 108 the page numbers
# 108 the page numbers
# Wood County
# Yoakum County
# Wood County {'Retail & recreation': -38, 'Grocery & pharmacy': -11, 'Workplace': -37}
# Yoakum County {'Grocery & pharmacy': -12}
# 4
# {'Wood County': {'Retail & recreation': -38, 'Grocery & pharmacy': -11, 'Workplace': -37}, 'Yoakum County': {'Grocery & pharmacy': -12}}
# 4
# 109 the page numbers
# 109 the page numbers
# 109 the page numbers
# 109 the page numbers
# Young County
# Zapata County
# Young County {'Retail & recreation': -60, 'Grocery & pharmacy': 43, 'Workplace': -32}
# Zapata County {'Retail & recreation': -55, 'Grocery & pharmacy': -30}
# 5
# {'Young County': {'Retail & recreation': -60, 'Grocery & pharmacy': 43, 'Workplace': -32}, 'Zapata County': {'Retail & recreation': -55, 'Grocery & pharmacy': -30}}
# 5
# 110 the page numbers
# 110 the page numbers
# 110 the page numbers
# 110 the page numbers
# 110 the page numbers
# Zavala County
# *
# Zavala County {'Grocery & pharmacy': -16}
# * {}
# 1
# {'Zavala County': {'Grocery & pharmacy': -16}, '*': {}}
# 0
# Parsed 638 plots for 188 counties in Texas
#     state           county             category  change  changecalc  \
# 0   Texas  Anderson County  Retail & recreation     -39  -40.993347
# 1   Texas  Anderson County   Grocery & pharmacy      -6   -5.767015
# 2   Texas  Anderson County            Workplace     -26  -27.372258
# 3   Texas   Andrews County  Retail & recreation     -45  -47.290382
# 4   Texas   Andrews County   Grocery & pharmacy     -40  -41.525905
# ..    ...              ...                  ...     ...         ...
# 95  Texas      Cass County   Grocery & pharmacy      -3   -2.834467
# 96  Texas      Cass County     Transit stations     -25  -26.041667
# 97  Texas      Cass County            Workplace     -36  -37.037035
# 98  Texas  Chambers County  Retail & recreation     -47  -49.424032
# 99  Texas  Chambers County   Grocery & pharmacy     -22  -23.279673
#
#                                                 dates  \
# 0   [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# 1   [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# 2   [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# 3   [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# 4   [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# ..                                                ...
# 95  [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# 96  [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# 97  [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# 98  [2020-02-23, 2020-02-24, 2020-02-25, 2020-02-2...
# 99  [2020-02-24, 2020-02-25, 2020-02-26, 2020-02-2...
#
#                                                values  page
# 0   [-4.357, 9.533, 11.36, 22.25, 17.169, 15.157, ...     2
# 1   [3.604, -0.947, -0.629, 7.034, 5.682, 14.153, ...     2
# 2   [0.76, 2.06, 3.072, 5.378, 2.52, 4.191, 2.741,...     2
# 3   [-1.917, 6.448, 1.82, 18.136, 17.054, 12.731, ...     2
# 4   [-9.15, 0.62, -4.315, -1.19, 7.485, 2.943, 0.6...     2
# ..                                                ...   ...
# 95  [2.126, 6.623, -3.492, 12.112, 6.401, 11.018, ...    16
# 96  [1.736, -1.628, -3.906, 5.274, 13.355, -4.112,...    16
# 97  [-3.472, 3.09, -0.425, 0.837, 0.85, 5.556, 7.5...    16
# 98  [10.378, -0.136, 8.625, 15.07, 13.19, 11.161, ...    17
# 99  [-8.17, 1.216, 0.823, 2.804, 6.944, 5.974, 6.3...    17
#
# [100 rows x 8 columns]

# %%
#Script for scraping the initial two pages of the pdf file
def parse_page_total(doc, ipage, verbose=False):
    """
    First two pages
    """
    category_list = [
        "Retail & recreation",
        "Grocery & pharmacy",
        "Parks",
        "Transit stations",
        "Workplaces",  # They have workplaces there instead of workplace
        "Residential",
    ]

    curr_category = None
    data = defaultdict(lambda: defaultdict(list))
    pagetext = doc.getPageText(ipage)
    lines = pagetext.splitlines()
    tickdates = []
    for line in lines:

        if ("* Not enough data") in line: continue
        if ("needs a significant volume of data") in line: continue
        # Added this condition to check for the extra text in the right of the page
        if 'Mobility trends ' in line or 'hubs' in line: continue
        # If found the category line, add it to the dictionary, else keep iterating over.
        if any(line.startswith(category) for category in categoriy_list):
            curr_category = line
        # Checking for x axis in the details
        elif line[:3] in ('Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat', 'Sun'):
            tickdates.append(line)
        elif line[0] not in ('+', '-'):
            continue
        elif curr_category:
            data[curr_category] = data.get(curr_category, []) + [line]

    newdata = {}
    for category in data:
        # Skipping the ones with no data. We get to know that based on the space and * in the Pdf
        if category.endswith(" "): continue
        temp = data[category][0]
        percent = int(temp.split()[0].replace("%",""))
        newdata[category.strip()] = percent
    data = newdata

    tomatch = []
    # Create a list of counties and the available categories for the given county
    for category in categories:
        if category in data:
            tomatch.append([category,data[category]])

    # Get the readable plots from the page ( Since there are broken and empty plots in the page)
    readableplots = []
    xrefs = sorted(doc.getPageXObjectList(ipage), key=lambda x:int(x[1].replace("X","")))
    for _, xref in enumerate(xrefs):
        stream = doc.xrefStream(xref[0]).decode()
        info = parse_streaming_data(stream)
        if not info["good"]:
            continue
        readableplots.append(info)
    
    print(len(readableplots))
    
    ret = []
    
    if len(tomatch) != len(readableplots):
        return ret
    
    for m,g in zip(tomatch,plots):
        xs = g["data"][:,0]
        ys = g["data"][:,1]
        maxys = ys[np.where(xs==xs.max())[0]]
        maxy = maxys[np.argmax(np.abs(maxys))]
        
        
        # Parse the dates as text and then based on min to max value, create a range of dates and store it in the dictionary
        ts = list(map(lambda x: pd.Timestamp(x.split(None,1)[-1] + ", 2020"), tickdates))
        low, high = min(ts), max(ts)
        dr = list(map(lambda x:str(x).split()[0], pd.date_range(low, high, freq="D")))
        lutpairs = list(zip(np.linspace(0,200,len(dr)),dr))

        dates = []
        values = []
        asort = xs.argsort()
        xs = xs[asort]
        ys = ys[asort]
        for x,y in zip(xs,ys):
            date = min(lutpairs, key=lambda v:abs(v[0]-x))[1]
            dates.append(date)
            values.append(round(y,3))

        ret.append(dict(
            category=m[0],change=m[1],
            values=values,
            dates=dates,
            changecalc=maxy,
        ))
    return ret


# Create the dataframe for the country data.

def parse_country(country):
    doc = fitz.Document(f"mobility_pdfs/2020-04-05_{country}_Mobility_Report_en.pdf")
    data = []
    for i in range(2):
        for entry in parse_page_total(doc, i):
            entry['state'] = state
            entry['page'] = i
            entry['county'] = 'total'
            data.append(entry)
    df = pd.DataFrame(data)
    return df

# %%
# Will replace this with a loop once a list for the codes for all the other countries
df_ES = parse_state_total("ES")
df_IT = parse_state_total("IT")
df_FR = parse_state_total("FR")
df_DE = parse_state_total("DE")

combined = [df_US, df_ES, df_IT, df_FR, df_DE]
df_comb = pd.concat(combined)
df_comb.head(100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3b479d342cde> in <module>
#       1 # Will replace this with a loop once a list for the codes for all the other countries
# ----> 2 df_ES = parse_state_total("ES")
#       3 df_IT = parse_state_total("IT")
#       4 df_FR = parse_state_total("FR")
#       5 df_DE = parse_state_total("DE")
#
# NameError: name 'parse_state_total' is not defined
